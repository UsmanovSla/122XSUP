# %% [markdown]
# ## 122XSUP - Strojové učení a umělá inteligence v prostředí Python

# %% [markdown]
# <h5 style='color:orange'><em>Week 8: Machine learning algorithms.</em></h5>

# %% [markdown]
# <img src="img/algorithms.png" width="600px">

# %% [markdown]
# <img src="img/supervise.png" width="600px">

# %% [markdown]
# <img src="img/unsupervised.jpg" width="600px">

# %% [markdown]
# ### 01 Regression
#
# * **Simple linear regression** (<a href='DS_08_01_Simple_Linear_Regression.ipynb'>DS_08_01_Simple_Linear_Regression.ipynb</a>)
# * **Mulitple linearrRegression** (<a href='DS_08_02_Mulitple_Linear_Regression.ipynb'>DS_08_02_Mulitple_Linear_Regression.ipynb</a>)
# * **Regression trees** (<a href='DS_08_03_Regression_Trees.ipynb'>DS_08_03_Regression_Trees.ipynb</a>)

# %% [markdown]
# ### 02 Classification
#
# * **Logistic Regression** (<a href='DS_08_04_Logistic_Regression.ipynb'>DS_08_04_Logistic_Regression.ipynb</a>)
# * **K-Nearest Neighbors** (<a href='DS_08_05_KNN.ipynb'>DS_08_05_KNN.ipynb</a>)
# * **Support Vector Machine** (<a href='DS_08_06_SVM.ipynb'>DS_08_06_SVM.ipynb</a>)
# * **Multi Class Prediction** (<a href='DS_08_07_Multi_Class_Classification.ipynb'>DS_08_07_Multi_Class_Classification.ipynb</a>)
# * **Decision Trees** (<a href='DS_08_08_Decision_Trees.ipynb'>DS_08_08_Decision_Trees.ipynb</a>)

# %% [markdown]
# ### 03 Clustering
#
# * **K-means** (<a href='DS_08_09_K_Means.ipynb'>DS_08_09_K_Means.ipynb</a>)

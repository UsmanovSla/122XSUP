# %% [markdown]
# # Task 05: Data Analysis - Concrete

# %% [markdown]
# ### About this Dataset
# File: data/concrete_data.csv

# %% [markdown]
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:

# %% [markdown]
# *
# *
# *
# *
# *

# %% [markdown]
# We have xxx rows and xxx columns. The first xxx columns represent the features and the last column represent the target/label.

# %%
# write commented pip command for instalation packages

# %%
# Import libraries

# %%
# read from file to dataframe data/concrete_data.csv

# %%
# show the first 10 rows using dataframe.head() method
print("The first 10 rows of the dataframe")

# %% [markdown]
# So the first concrete sample has xxx cubic meter of cement, xxx cubic meter of blast furnace slag, xxx cubic meter of fly ash, xxx cubic meter of water, xxx cubic meter of superplaticizer, xxx cubic meter of coarse aggregate, xxx cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of xxx MPa.

# %%
# show the last 5 rows
print("The last 5 rows of the dataframe")

# %%
# To view the dimensions of the dataframe with shape

# %% [markdown]
# ### Statistical Overview of dataset

# %%
# info

# %%
# describe

# %% [markdown]
# ##### Identify and handle missing values

# %%
# identify these missing values: create new dataframe missing_data

# %% [markdown]
# ##### Count missing values in each column

# %%
# write a function for counting missing value in dataframe

def count_missing(df: pd.DataFrame) -> int:
    pass

# %%
# call function and print report about missing value in dataframe

# %% [markdown]
# ##### Correct data format
#
# * check all data is in the correct format (int, float, text or other)
# * change **float** to **int** in column 'Water'

# %%
# check data in dataframe

# %%
# change data type

# %% [markdown]
# ##### Calculation and operetion with dataframe
#
# * create new column in dataframe 'Hi Strength'
# * fill new collum with:
#     * 1 if strength >= 30 MPa
#     * 0 if strength < 30 MPa

# %% [markdown]
# ##### Save data as new dataframe to file: data/concrete_data_clean.csv

# %%
# Save dataframe to file

# %% [markdown]
# ### Visualization

# %% [markdown]
# **Visualization** with **Seaborn** and **Matplotlib**

# %%
# %pip install matplotlib
# %pip install seaborn

# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels= 'Hi Strength'
plt.pie(df['Hi Strength'].value_counts(), labels=labels, autopct='%0.02f%%')
plt.legend()
plt.show()

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# ### Sources:

# %% [markdown]
# #### Author/Date/Organization

# %% [markdown]
# ###### Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2023-10-13 | 1.1 | Vjaceslav Usmanov| added task_05.csv |
# | 2023-10-14 | 1.2 | Vjaceslav Usmanov| changed Task_05.ipynb |

# %% [markdown]
# ## 122XSUP - Strojové učení a umělá inteligence v prostředí Python

# %% [markdown]
# <h5 style='color:orange'><em>Week 10: Introduction to Deep Learning</em></h5>

# %% [markdown]
# <img src="img/deep-1.png" width="600px">

# %% [markdown]
# <img src="img/deep-2.png" width="600px">

# %% [markdown]
# <img src="img/deep-3.png" width="600px">

# %% [markdown]
# <img src="img/deep-4.png" width="600px">

# %% [markdown]
# ### Neural Network

# %% [markdown]
# <img src="img/deep-5.png" width="600px">

# %% [markdown]
# <img src="img/deep-6.png" width="600px">

# %% [markdown]
# ### Artificial Neural Network

# %% [markdown]
# <img src="img/deep-7.jpg" width="600px"><br>
# <img src="img/other/deep-002.png" width="600px">

# %% [markdown]
# ### Forward propagation, Backpropagation and Activation functions.

# %% [markdown]
# <img src="img/deep-8.png" width="600px">

# %% [markdown]
# <img src="img/deep-9.png" width="600px">

# %% [markdown]
# <img src="img/deep-01.png" width="600px"><br>
# <img src="img/deep-02.png" width="600px"><br>
# <img src="img/deep-03.png" width="600px"><br>
# <img src="img/deep-03-2.png" width="600px"><br>
# <img src="img/deep-04.png" width="600px">

# %% [markdown]
# ### Vanishing gradient

# %% [markdown]
# Vanishing gradient problem is a phenomenon that occurs during the training of deep neural networks, where the gradients that are used to update the network become extremely small or "vanish" as they are backpropogated from the output layers to the earlier layers.

# %% [markdown]
# <img src="img/deep-05.png" width="600px">

# %% [markdown]
# ### Activation functions

# %% [markdown]
# <img src="img/deep-06.png" width="600px"><br>
# <img src="img/deep-07.png" width="600px"><br>
# <img src="img/deep-08.png" width="600px"><br>
# <img src="img/deep-09.jpg" width="600px">

# %% [markdown]
# Example: **My first Neural Network** (<a href='DS_10_01_Forward_Propgation.ipynb'>DS_10_01_Forward_Propgation.ipynb</a>)

# %% [markdown]
# # Deep Learning Libraries
#
# * **Keras** (<a href='https://keras.io/'>https://keras.io/</a>)
# * **TensorFlow** (<a href='https://www.tensorflow.org/'>https://www.tensorflow.org/</a>)
# * **PyTorch** (<a href='https://pytorch.org/'>https://pytorch.org/</a>)

# %% [markdown]
# <img src='img/other/keras.png' width=200px> <img src='img/other/tensorflow.png' width=200px> <img src='img/other/pytorch.png' width=200px>

# %% [markdown]
# <img src='img/other/deep-001.png' width=600px>

# %% [markdown]
# Example:
# * **Keras: Regression** / Supervised (<a href='DS_10_02_Keras_Regression.ipynb'>DS_10_02_Keras_Regression.ipynb</a>)
# * **Keras: Classification** / Supervised(<a href='DS_10_03_Keras_Classification.ipynb'>DS_10_03_Keras_Classification.ipynb</a>)
# * **Keras: Convolutional Neural Networks (CNNs)** / Supervised (<a href='DS_10_04_Keras_CNNs.ipynb'>DS_10_04_Keras_CNN.ipynb</a>)
#
# Other models:
# * **Recurrent Neural Networks** / Supervised

# %% [markdown]
# <img src='img/other/deep-003.png' width=600px>

# %% [markdown]
# * **Autoencoders**  / Unsupervised

# %% [markdown]
# <img src='img/other/deep-005.png' width=600px><br>
# <img src='img/other/deep-004.png' width=600px><br>
# <img src='img/other/deep-006.png' width=600px>

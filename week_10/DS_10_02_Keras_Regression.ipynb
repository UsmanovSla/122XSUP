# %% [markdown]
# # Regression Models with Keras

# %% [markdown]
# ## Introduction

# %% [markdown]
# Despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. Building a very complex deep learning network can be achieved with Keras with only few lines of code.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below.

# %pip install numpy
# %pip install pandas
# %pip install keras

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in previous labs.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors
n_cols
# Out:
# 8

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library.

# %% [markdown]
# **TensorFlow currently (23.11.2023) support python < 3.11 so try downgrading your python edition if your kernel is 3.12**

# %% [markdown]
# <img src='img/other/tensorflow-2.png' width='600px'>

# %%
#  Install TensorFlow library
# %pip install --upgrade pip
# %pip install tensorflow

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
import keras
# Out:
# WARNING:tensorflow:From c:\Users\usman\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# WARNING:tensorflow:From c:\Users\usman\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\usman\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\usman\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 23/23 - 1s - loss: 1639.8433 - val_loss: 1120.1454 - 684ms/epoch - 30ms/step
# Epoch 2/200
# 23/23 - 0s - loss: 1484.8044 - val_loss: 968.0248 - 51ms/epoch - 2ms/step
# Epoch 3/200
# 23/23 - 0s - loss: 1229.1313 - val_loss: 743.8648 - 50ms/epoch - 2ms/step
# Epoch 4/200
# 23/23 - 0s - loss: 883.0132 - val_loss: 480.6365 - 50ms/epoch - 2ms/step
# Epoch 5/200
# 23/23 - 0s - loss: 519.9854 - val_loss: 268.6380 - 49ms/epoch - 2ms/step
# Epoch 6/200
# 23/23 - 0s - loss: 294.9795 - val_loss: 177.6790 - 49ms/epoch - 2ms/step
# Epoch 7/200
# 23/23 - 0s - loss: 227.2301 - val_loss: 166.6868 - 48ms/epoch - 2ms/step
# Epoch 8/200
# 23/23 - 0s - loss: 211.9361 - val_loss: 169.3335 - 48ms/epoch - 2ms/step
# Epoch 9/200
# 23/23 - 0s - loss: 201.0210 - val_loss: 165.8582 - 48ms/epoch - 2ms/step
# Epoch 10/200
# 23/23 - 0s - loss: 193.9124 - val_loss: 163.7656 - 49ms/epoch - 2ms/step
# Epoch 11/200
# 23/23 - 0s - loss: 186.3467 - val_loss: 164.0130 - 48ms/epoch - 2ms/step
# Epoch 12/200
# 23/23 - 0s - loss: 181.4572 - val_loss: 162.3615 - 48ms/epoch - 2ms/step
# Epoch 13/200
# 23/23 - 0s - loss: 177.0155 - val_loss: 161.9843 - 48ms/epoch - 2ms/step
# Epoch 14/200
# 23/23 - 0s - loss: 173.1514 - val_loss: 159.9473 - 50ms/epoch - 2ms/step
# Epoch 15/200
# 23/23 - 0s - loss: 169.5900 - val_loss: 158.9514 - 48ms/epoch - 2ms/step
# Epoch 16/200
# 23/23 - 0s - loss: 166.0543 - val_loss: 157.1294 - 48ms/epoch - 2ms/step
# Epoch 17/200
# 23/23 - 0s - loss: 162.8418 - val_loss: 155.6990 - 48ms/epoch - 2ms/step
# Epoch 18/200
# 23/23 - 0s - loss: 160.3279 - val_loss: 157.2432 - 49ms/epoch - 2ms/step
# Epoch 19/200
# 23/23 - 0s - loss: 158.6158 - val_loss: 155.3134 - 50ms/epoch - 2ms/step
# Epoch 20/200
# 23/23 - 0s - loss: 155.5577 - val_loss: 156.5432 - 50ms/epoch - 2ms/step
# Epoch 21/200
# 23/23 - 0s - loss: 154.0366 - val_loss: 153.5085 - 49ms/epoch - 2ms/step
# Epoch 22/200
# 23/23 - 0s - loss: 150.7412 - val_loss: 154.1545 - 50ms/epoch - 2ms/step
# Epoch 23/200
# 23/23 - 0s - loss: 149.2119 - val_loss: 150.7974 - 49ms/epoch - 2ms/step
# Epoch 24/200
# 23/23 - 0s - loss: 146.6716 - val_loss: 152.8978 - 49ms/epoch - 2ms/step
# Epoch 25/200
# 23/23 - 0s - loss: 144.2586 - val_loss: 150.8672 - 49ms/epoch - 2ms/step
# Epoch 26/200
# 23/23 - 0s - loss: 142.1230 - val_loss: 152.8276 - 49ms/epoch - 2ms/step
# Epoch 27/200
# 23/23 - 0s - loss: 140.5938 - val_loss: 150.9264 - 50ms/epoch - 2ms/step
# Epoch 28/200
# 23/23 - 0s - loss: 138.1201 - val_loss: 152.0625 - 49ms/epoch - 2ms/step
# Epoch 29/200
# 23/23 - 0s - loss: 136.1423 - val_loss: 154.4961 - 50ms/epoch - 2ms/step
# Epoch 30/200
# 23/23 - 0s - loss: 134.2740 - val_loss: 151.0116 - 49ms/epoch - 2ms/step
# Epoch 31/200
# 23/23 - 0s - loss: 131.7029 - val_loss: 151.7462 - 50ms/epoch - 2ms/step
# Epoch 32/200
# 23/23 - 0s - loss: 129.6017 - val_loss: 151.5192 - 49ms/epoch - 2ms/step
# Epoch 33/200
# 23/23 - 0s - loss: 127.8110 - val_loss: 150.9535 - 47ms/epoch - 2ms/step
# Epoch 34/200
# 23/23 - 0s - loss: 125.1444 - val_loss: 151.4737 - 48ms/epoch - 2ms/step
# Epoch 35/200
# 23/23 - 0s - loss: 123.3068 - val_loss: 152.1839 - 49ms/epoch - 2ms/step
# Epoch 36/200
# 23/23 - 0s - loss: 120.5648 - val_loss: 151.7933 - 48ms/epoch - 2ms/step
# Epoch 37/200
# 23/23 - 0s - loss: 117.9498 - val_loss: 153.1985 - 50ms/epoch - 2ms/step
# Epoch 38/200
# 23/23 - 0s - loss: 115.9069 - val_loss: 154.1059 - 48ms/epoch - 2ms/step
# Epoch 39/200
# 23/23 - 0s - loss: 113.2530 - val_loss: 149.8322 - 49ms/epoch - 2ms/step
# Epoch 40/200
# 23/23 - 0s - loss: 110.4945 - val_loss: 149.1032 - 50ms/epoch - 2ms/step
# Epoch 41/200
# 23/23 - 0s - loss: 107.0868 - val_loss: 151.3219 - 50ms/epoch - 2ms/step
# Epoch 42/200
# 23/23 - 0s - loss: 104.5762 - val_loss: 152.4517 - 51ms/epoch - 2ms/step
# Epoch 43/200
# 23/23 - 0s - loss: 101.4025 - val_loss: 152.3344 - 50ms/epoch - 2ms/step
# Epoch 44/200
# 23/23 - 0s - loss: 99.3534 - val_loss: 145.6752 - 51ms/epoch - 2ms/step
# Epoch 45/200
# 23/23 - 0s - loss: 97.3637 - val_loss: 150.7646 - 50ms/epoch - 2ms/step
# Epoch 46/200
# 23/23 - 0s - loss: 93.4559 - val_loss: 154.4532 - 50ms/epoch - 2ms/step
# Epoch 47/200
# 23/23 - 0s - loss: 91.3786 - val_loss: 150.5453 - 50ms/epoch - 2ms/step
# Epoch 48/200
# 23/23 - 0s - loss: 88.6532 - val_loss: 153.9718 - 49ms/epoch - 2ms/step
# Epoch 49/200
# 23/23 - 0s - loss: 85.8687 - val_loss: 156.5029 - 49ms/epoch - 2ms/step
# Epoch 50/200
# 23/23 - 0s - loss: 83.5799 - val_loss: 147.2774 - 48ms/epoch - 2ms/step
# Epoch 51/200
# 23/23 - 0s - loss: 81.1321 - val_loss: 151.0673 - 49ms/epoch - 2ms/step
# Epoch 52/200
# 23/23 - 0s - loss: 78.6435 - val_loss: 151.8402 - 50ms/epoch - 2ms/step
# Epoch 53/200
# 23/23 - 0s - loss: 76.4417 - val_loss: 154.0957 - 49ms/epoch - 2ms/step
# Epoch 54/200
# 23/23 - 0s - loss: 73.7251 - val_loss: 153.3402 - 48ms/epoch - 2ms/step
# Epoch 55/200
# 23/23 - 0s - loss: 73.0269 - val_loss: 150.7442 - 50ms/epoch - 2ms/step
# Epoch 56/200
# 23/23 - 0s - loss: 69.6379 - val_loss: 153.0041 - 47ms/epoch - 2ms/step
# Epoch 57/200
# 23/23 - 0s - loss: 67.1989 - val_loss: 149.1450 - 48ms/epoch - 2ms/step
# Epoch 58/200
# 23/23 - 0s - loss: 65.8469 - val_loss: 158.2213 - 49ms/epoch - 2ms/step
# Epoch 59/200
# 23/23 - 0s - loss: 63.6064 - val_loss: 154.6111 - 50ms/epoch - 2ms/step
# Epoch 60/200
# 23/23 - 0s - loss: 61.6599 - val_loss: 157.1582 - 48ms/epoch - 2ms/step
# Epoch 61/200
# 23/23 - 0s - loss: 59.9993 - val_loss: 160.9013 - 49ms/epoch - 2ms/step
# Epoch 62/200
# 23/23 - 0s - loss: 58.0266 - val_loss: 149.7208 - 48ms/epoch - 2ms/step
# Epoch 63/200
# 23/23 - 0s - loss: 56.6354 - val_loss: 156.8909 - 53ms/epoch - 2ms/step
# Epoch 64/200
# 23/23 - 0s - loss: 55.2992 - val_loss: 151.5834 - 48ms/epoch - 2ms/step
# Epoch 65/200
# 23/23 - 0s - loss: 54.0859 - val_loss: 165.5180 - 48ms/epoch - 2ms/step
# Epoch 66/200
# 23/23 - 0s - loss: 52.8255 - val_loss: 160.6907 - 49ms/epoch - 2ms/step
# Epoch 67/200
# 23/23 - 0s - loss: 52.0108 - val_loss: 154.2440 - 49ms/epoch - 2ms/step
# Epoch 68/200
# 23/23 - 0s - loss: 51.9274 - val_loss: 164.3398 - 49ms/epoch - 2ms/step
# Epoch 69/200
# 23/23 - 0s - loss: 49.6236 - val_loss: 157.1126 - 49ms/epoch - 2ms/step
# Epoch 70/200
# 23/23 - 0s - loss: 48.5094 - val_loss: 162.8967 - 48ms/epoch - 2ms/step
# Epoch 71/200
# 23/23 - 0s - loss: 47.6219 - val_loss: 167.4893 - 49ms/epoch - 2ms/step
# Epoch 72/200
# 23/23 - 0s - loss: 46.4879 - val_loss: 163.7460 - 51ms/epoch - 2ms/step
# Epoch 73/200
# 23/23 - 0s - loss: 45.9245 - val_loss: 155.3431 - 50ms/epoch - 2ms/step
# Epoch 74/200
# 23/23 - 0s - loss: 45.0512 - val_loss: 165.7890 - 49ms/epoch - 2ms/step
# Epoch 75/200
# 23/23 - 0s - loss: 44.1055 - val_loss: 159.3351 - 51ms/epoch - 2ms/step
# Epoch 76/200
# 23/23 - 0s - loss: 43.7746 - val_loss: 158.0164 - 49ms/epoch - 2ms/step
# Epoch 77/200
# 23/23 - 0s - loss: 43.2299 - val_loss: 165.5314 - 49ms/epoch - 2ms/step
# Epoch 78/200
# 23/23 - 0s - loss: 41.9200 - val_loss: 161.0811 - 50ms/epoch - 2ms/step
# Epoch 79/200
# 23/23 - 0s - loss: 41.3038 - val_loss: 163.6632 - 50ms/epoch - 2ms/step
# Epoch 80/200
# 23/23 - 0s - loss: 40.2133 - val_loss: 168.6385 - 49ms/epoch - 2ms/step
# Epoch 81/200
# 23/23 - 0s - loss: 40.0378 - val_loss: 161.6831 - 49ms/epoch - 2ms/step
# Epoch 82/200
# 23/23 - 0s - loss: 39.6018 - val_loss: 165.1395 - 49ms/epoch - 2ms/step
# Epoch 83/200
# 23/23 - 0s - loss: 38.7386 - val_loss: 170.8398 - 49ms/epoch - 2ms/step
# Epoch 84/200
# 23/23 - 0s - loss: 39.0420 - val_loss: 173.1596 - 52ms/epoch - 2ms/step
# Epoch 85/200
# 23/23 - 0s - loss: 37.6017 - val_loss: 163.0072 - 54ms/epoch - 2ms/step
# Epoch 86/200
# 23/23 - 0s - loss: 37.2136 - val_loss: 173.1418 - 53ms/epoch - 2ms/step
# Epoch 87/200
# 23/23 - 0s - loss: 36.6418 - val_loss: 155.6612 - 56ms/epoch - 2ms/step
# Epoch 88/200
# 23/23 - 0s - loss: 36.7905 - val_loss: 171.5733 - 50ms/epoch - 2ms/step
# Epoch 89/200
# 23/23 - 0s - loss: 35.9867 - val_loss: 169.3764 - 51ms/epoch - 2ms/step
# Epoch 90/200
# 23/23 - 0s - loss: 35.6178 - val_loss: 165.6679 - 50ms/epoch - 2ms/step
# Epoch 91/200
# 23/23 - 0s - loss: 35.5937 - val_loss: 163.4360 - 49ms/epoch - 2ms/step
# Epoch 92/200
# 23/23 - 0s - loss: 34.7042 - val_loss: 170.2807 - 50ms/epoch - 2ms/step
# Epoch 93/200
# 23/23 - 0s - loss: 34.4155 - val_loss: 167.8326 - 49ms/epoch - 2ms/step
# Epoch 94/200
# 23/23 - 0s - loss: 33.8689 - val_loss: 165.5325 - 51ms/epoch - 2ms/step
# Epoch 95/200
# 23/23 - 0s - loss: 34.0705 - val_loss: 162.5378 - 50ms/epoch - 2ms/step
# Epoch 96/200
# 23/23 - 0s - loss: 34.0314 - val_loss: 167.8519 - 50ms/epoch - 2ms/step
# Epoch 97/200
# 23/23 - 0s - loss: 33.0282 - val_loss: 170.0304 - 51ms/epoch - 2ms/step
# Epoch 98/200
# 23/23 - 0s - loss: 32.9926 - val_loss: 174.1685 - 51ms/epoch - 2ms/step
# Epoch 99/200
# 23/23 - 0s - loss: 32.8401 - val_loss: 161.3197 - 53ms/epoch - 2ms/step
# Epoch 100/200
# 23/23 - 0s - loss: 32.5350 - val_loss: 171.8714 - 53ms/epoch - 2ms/step
# Epoch 101/200
# 23/23 - 0s - loss: 32.3737 - val_loss: 164.9737 - 49ms/epoch - 2ms/step
# Epoch 102/200
# 23/23 - 0s - loss: 31.7086 - val_loss: 172.5506 - 49ms/epoch - 2ms/step
# Epoch 103/200
# 23/23 - 0s - loss: 31.8786 - val_loss: 169.3026 - 51ms/epoch - 2ms/step
# Epoch 104/200
# 23/23 - 0s - loss: 31.2903 - val_loss: 172.8061 - 50ms/epoch - 2ms/step
# Epoch 105/200
# 23/23 - 0s - loss: 31.1348 - val_loss: 167.1915 - 50ms/epoch - 2ms/step
# Epoch 106/200
# 23/23 - 0s - loss: 30.5484 - val_loss: 173.7744 - 50ms/epoch - 2ms/step
# Epoch 107/200
# 23/23 - 0s - loss: 30.7437 - val_loss: 185.0353 - 51ms/epoch - 2ms/step
# Epoch 108/200
# 23/23 - 0s - loss: 31.0558 - val_loss: 168.5041 - 50ms/epoch - 2ms/step
# Epoch 109/200
# 23/23 - 0s - loss: 30.4977 - val_loss: 168.6780 - 51ms/epoch - 2ms/step
# Epoch 110/200
# 23/23 - 0s - loss: 30.2589 - val_loss: 166.9942 - 51ms/epoch - 2ms/step
# Epoch 111/200
# 23/23 - 0s - loss: 29.9261 - val_loss: 168.8573 - 53ms/epoch - 2ms/step
# Epoch 112/200
# 23/23 - 0s - loss: 29.4001 - val_loss: 160.9946 - 48ms/epoch - 2ms/step
# Epoch 113/200
# 23/23 - 0s - loss: 28.9805 - val_loss: 180.0674 - 54ms/epoch - 2ms/step
# Epoch 114/200
# 23/23 - 0s - loss: 29.3909 - val_loss: 178.3782 - 50ms/epoch - 2ms/step
# Epoch 115/200
# 23/23 - 0s - loss: 28.7459 - val_loss: 174.6421 - 51ms/epoch - 2ms/step
# Epoch 116/200
# 23/23 - 0s - loss: 28.8953 - val_loss: 177.9019 - 50ms/epoch - 2ms/step
# Epoch 117/200
# 23/23 - 0s - loss: 28.1151 - val_loss: 175.2338 - 51ms/epoch - 2ms/step
# Epoch 118/200
# 23/23 - 0s - loss: 28.5917 - val_loss: 167.6510 - 52ms/epoch - 2ms/step
# Epoch 119/200
# 23/23 - 0s - loss: 28.7514 - val_loss: 171.1810 - 50ms/epoch - 2ms/step
# Epoch 120/200
# 23/23 - 0s - loss: 27.8132 - val_loss: 177.1171 - 52ms/epoch - 2ms/step
# Epoch 121/200
# 23/23 - 0s - loss: 27.6513 - val_loss: 175.1147 - 52ms/epoch - 2ms/step
# Epoch 122/200
# 23/23 - 0s - loss: 27.4193 - val_loss: 176.4505 - 54ms/epoch - 2ms/step
# Epoch 123/200
# 23/23 - 0s - loss: 27.4340 - val_loss: 184.2615 - 53ms/epoch - 2ms/step
# Epoch 124/200
# 23/23 - 0s - loss: 26.9879 - val_loss: 181.4824 - 50ms/epoch - 2ms/step
# Epoch 125/200
# 23/23 - 0s - loss: 26.9620 - val_loss: 184.3069 - 50ms/epoch - 2ms/step
# Epoch 126/200
# 23/23 - 0s - loss: 26.9551 - val_loss: 186.5333 - 50ms/epoch - 2ms/step
# Epoch 127/200
# 23/23 - 0s - loss: 27.1892 - val_loss: 193.6850 - 49ms/epoch - 2ms/step
# Epoch 128/200
# 23/23 - 0s - loss: 27.1715 - val_loss: 188.5967 - 49ms/epoch - 2ms/step
# Epoch 129/200
# 23/23 - 0s - loss: 26.3743 - val_loss: 183.1874 - 51ms/epoch - 2ms/step
# Epoch 130/200
# 23/23 - 0s - loss: 26.2488 - val_loss: 174.6347 - 50ms/epoch - 2ms/step
# Epoch 131/200
# 23/23 - 0s - loss: 26.7725 - val_loss: 190.7065 - 50ms/epoch - 2ms/step
# Epoch 132/200
# 23/23 - 0s - loss: 26.2188 - val_loss: 186.1196 - 49ms/epoch - 2ms/step
# Epoch 133/200
# 23/23 - 0s - loss: 25.5786 - val_loss: 185.1773 - 49ms/epoch - 2ms/step
# Epoch 134/200
# 23/23 - 0s - loss: 25.3679 - val_loss: 175.5080 - 53ms/epoch - 2ms/step
# Epoch 135/200
# 23/23 - 0s - loss: 25.6426 - val_loss: 178.3759 - 51ms/epoch - 2ms/step
# Epoch 136/200
# 23/23 - 0s - loss: 25.2262 - val_loss: 183.2949 - 50ms/epoch - 2ms/step
# Epoch 137/200
# 23/23 - 0s - loss: 25.4560 - val_loss: 188.3441 - 49ms/epoch - 2ms/step
# Epoch 138/200
# 23/23 - 0s - loss: 25.8698 - val_loss: 186.2523 - 48ms/epoch - 2ms/step
# Epoch 139/200
# 23/23 - 0s - loss: 24.5335 - val_loss: 182.4901 - 51ms/epoch - 2ms/step
# Epoch 140/200
# 23/23 - 0s - loss: 24.4287 - val_loss: 193.2338 - 50ms/epoch - 2ms/step
# Epoch 141/200
# 23/23 - 0s - loss: 24.2350 - val_loss: 173.3413 - 51ms/epoch - 2ms/step
# Epoch 142/200
# 23/23 - 0s - loss: 24.3904 - val_loss: 186.5365 - 48ms/epoch - 2ms/step
# Epoch 143/200
# 23/23 - 0s - loss: 24.3265 - val_loss: 183.6866 - 49ms/epoch - 2ms/step
# Epoch 144/200
# 23/23 - 0s - loss: 23.9158 - val_loss: 185.5732 - 50ms/epoch - 2ms/step
# Epoch 145/200
# 23/23 - 0s - loss: 23.6026 - val_loss: 183.1341 - 48ms/epoch - 2ms/step
# Epoch 146/200
# 23/23 - 0s - loss: 23.5274 - val_loss: 192.3929 - 48ms/epoch - 2ms/step
# Epoch 147/200
# 23/23 - 0s - loss: 23.9584 - val_loss: 197.2158 - 49ms/epoch - 2ms/step
# Epoch 148/200
# 23/23 - 0s - loss: 23.3760 - val_loss: 189.3411 - 48ms/epoch - 2ms/step
# Epoch 149/200
# 23/23 - 0s - loss: 23.1637 - val_loss: 195.1209 - 49ms/epoch - 2ms/step
# Epoch 150/200
# 23/23 - 0s - loss: 23.4703 - val_loss: 183.2640 - 50ms/epoch - 2ms/step
# Epoch 151/200
# 23/23 - 0s - loss: 23.0427 - val_loss: 191.5823 - 48ms/epoch - 2ms/step
# Epoch 152/200
# 23/23 - 0s - loss: 23.6553 - val_loss: 197.4989 - 49ms/epoch - 2ms/step
# Epoch 153/200
# 23/23 - 0s - loss: 24.1794 - val_loss: 197.4518 - 47ms/epoch - 2ms/step
# Epoch 154/200
# 23/23 - 0s - loss: 22.6682 - val_loss: 196.1520 - 56ms/epoch - 2ms/step
# Epoch 155/200
# 23/23 - 0s - loss: 22.4957 - val_loss: 189.3947 - 50ms/epoch - 2ms/step
# Epoch 156/200
# 23/23 - 0s - loss: 22.2200 - val_loss: 201.1338 - 50ms/epoch - 2ms/step
# Epoch 157/200
# 23/23 - 0s - loss: 21.8616 - val_loss: 188.6355 - 48ms/epoch - 2ms/step
# Epoch 158/200
# 23/23 - 0s - loss: 22.3252 - val_loss: 191.8792 - 49ms/epoch - 2ms/step
# Epoch 159/200
# 23/23 - 0s - loss: 21.9757 - val_loss: 193.2931 - 50ms/epoch - 2ms/step
# Epoch 160/200
# 23/23 - 0s - loss: 22.0599 - val_loss: 197.5015 - 53ms/epoch - 2ms/step
# Epoch 161/200
# 23/23 - 0s - loss: 21.7737 - val_loss: 198.0171 - 51ms/epoch - 2ms/step
# Epoch 162/200
# 23/23 - 0s - loss: 21.7179 - val_loss: 193.4734 - 51ms/epoch - 2ms/step
# Epoch 163/200
# 23/23 - 0s - loss: 21.8304 - val_loss: 199.3216 - 48ms/epoch - 2ms/step
# Epoch 164/200
# 23/23 - 0s - loss: 21.7792 - val_loss: 192.0516 - 50ms/epoch - 2ms/step
# Epoch 165/200
# 23/23 - 0s - loss: 21.0886 - val_loss: 195.1891 - 51ms/epoch - 2ms/step
# Epoch 166/200
# 23/23 - 0s - loss: 20.8531 - val_loss: 204.7909 - 52ms/epoch - 2ms/step
# Epoch 167/200
# 23/23 - 0s - loss: 21.0387 - val_loss: 195.5200 - 50ms/epoch - 2ms/step
# Epoch 168/200
# 23/23 - 0s - loss: 20.8729 - val_loss: 189.8062 - 49ms/epoch - 2ms/step
# Epoch 169/200
# 23/23 - 0s - loss: 20.8519 - val_loss: 193.6312 - 49ms/epoch - 2ms/step
# Epoch 170/200
# 23/23 - 0s - loss: 20.7040 - val_loss: 202.2557 - 49ms/epoch - 2ms/step
# Epoch 171/200
# 23/23 - 0s - loss: 20.4628 - val_loss: 199.5695 - 50ms/epoch - 2ms/step
# Epoch 172/200
# 23/23 - 0s - loss: 20.2586 - val_loss: 190.9466 - 48ms/epoch - 2ms/step
# Epoch 173/200
# 23/23 - 0s - loss: 20.4539 - val_loss: 190.6283 - 48ms/epoch - 2ms/step
# Epoch 174/200
# 23/23 - 0s - loss: 20.3816 - val_loss: 190.4085 - 49ms/epoch - 2ms/step
# Epoch 175/200
# 23/23 - 0s - loss: 19.8713 - val_loss: 203.0059 - 49ms/epoch - 2ms/step
# Epoch 176/200
# 23/23 - 0s - loss: 19.8477 - val_loss: 202.5802 - 47ms/epoch - 2ms/step
# Epoch 177/200
# 23/23 - 0s - loss: 19.7294 - val_loss: 210.2594 - 48ms/epoch - 2ms/step
# Epoch 178/200
# 23/23 - 0s - loss: 19.9274 - val_loss: 200.3902 - 49ms/epoch - 2ms/step
# Epoch 179/200
# 23/23 - 0s - loss: 19.8630 - val_loss: 208.3376 - 50ms/epoch - 2ms/step
# Epoch 180/200
# 23/23 - 0s - loss: 19.7045 - val_loss: 201.5017 - 50ms/epoch - 2ms/step
# Epoch 181/200
# 23/23 - 0s - loss: 19.8292 - val_loss: 187.0863 - 49ms/epoch - 2ms/step
# Epoch 182/200
# 23/23 - 0s - loss: 19.7652 - val_loss: 188.5819 - 48ms/epoch - 2ms/step
# Epoch 183/200
# 23/23 - 0s - loss: 19.8275 - val_loss: 188.9804 - 50ms/epoch - 2ms/step
# Epoch 184/200
# 23/23 - 0s - loss: 19.6116 - val_loss: 192.3923 - 49ms/epoch - 2ms/step
# Epoch 185/200
# 23/23 - 0s - loss: 19.0069 - val_loss: 193.3037 - 51ms/epoch - 2ms/step
# Epoch 186/200
# 23/23 - 0s - loss: 19.0182 - val_loss: 202.5158 - 48ms/epoch - 2ms/step
# Epoch 187/200
# 23/23 - 0s - loss: 19.0632 - val_loss: 201.5213 - 47ms/epoch - 2ms/step
# Epoch 188/200
# 23/23 - 0s - loss: 18.9800 - val_loss: 188.8356 - 48ms/epoch - 2ms/step
# Epoch 189/200
# 23/23 - 0s - loss: 19.8200 - val_loss: 193.6628 - 49ms/epoch - 2ms/step
# Epoch 190/200
# 23/23 - 0s - loss: 19.1912 - val_loss: 194.0633 - 49ms/epoch - 2ms/step
# Epoch 191/200
# 23/23 - 0s - loss: 18.8567 - val_loss: 185.9457 - 49ms/epoch - 2ms/step
# Epoch 192/200
# 23/23 - 0s - loss: 18.9224 - val_loss: 187.8108 - 50ms/epoch - 2ms/step
# Epoch 193/200
# 23/23 - 0s - loss: 18.7926 - val_loss: 190.9442 - 50ms/epoch - 2ms/step
# Epoch 194/200
# 23/23 - 0s - loss: 18.9329 - val_loss: 199.2638 - 50ms/epoch - 2ms/step
# Epoch 195/200
# 23/23 - 0s - loss: 18.2723 - val_loss: 207.3047 - 50ms/epoch - 2ms/step
# Epoch 196/200
# 23/23 - 0s - loss: 18.6388 - val_loss: 208.4300 - 53ms/epoch - 2ms/step
# Epoch 197/200
# 23/23 - 0s - loss: 18.3437 - val_loss: 194.8329 - 53ms/epoch - 2ms/step
# Epoch 198/200
# 23/23 - 0s - loss: 18.1901 - val_loss: 210.8904 - 49ms/epoch - 2ms/step
# Epoch 199/200
# 23/23 - 0s - loss: 18.8383 - val_loss: 204.9560 - 49ms/epoch - 2ms/step
# Epoch 200/200
# 23/23 - 0s - loss: 17.7853 - val_loss: 199.2371 - 49ms/epoch - 2ms/step

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork945-2022-01-01) to learn about other functions that you can use for prediction or evaluation.</strong>

# %%
model.evaluate(
    x=predictors_norm,
    y=target,
    batch_size=None,
    verbose="auto",
    sample_weight=None,
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False,
    return_dict=False
)
# Out:
# 33/33 [==============================] - 0s 779us/step - loss: 71.8883
# 71.88831329345703

# %%
model.predict(
    predictors_norm,
    batch_size=None,
    verbose="auto",
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False,
)
# Out:
# 33/33 [==============================] - 0s 758us/step
# array([[71.19268 ],
#        [71.2008  ],
#        [41.4787  ],
#        ...,
#        [37.309372],
#        [43.80279 ],
#        [42.03324 ]], dtype=float32)

# %%
target
# Out:
# 0       79.99
# 1       61.89
# 2       40.27
# 3       41.05
# 4       44.30
#         ...
# 1025    44.28
# 1026    31.18
# 1027    23.70
# 1028    32.77
# 1029    32.40
# Name: Strength, Length: 1030, dtype: float64
